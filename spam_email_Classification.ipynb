# %% [markdown]
# **By Sandeep Kumar M**

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam

# Load the dataset
data = pd.read_csv("/content/drive/MyDrive/spam_mail_project/spam_mail_data.csv")
data.shape
# Shuffle the dataset and take half of the data
shuffled_data = data.sample(frac=1, random_state=42).reset_index(drop=True)
half_data = shuffled_data.iloc[:len(shuffled_data) // 2]

# Preprocess data
labels = half_data["Category"].replace({"spam": 1, "ham": 0})  # Replace labels with 1 (spam) and 0 (ham)
messages = half_data["Message"]  # Extract the messages

# Split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(messages, labels, test_size=0.2, random_state=23, shuffle=True)

# Convert text data into numerical features using TF-IDF
vectorizer = TfidfVectorizer(min_df=1, lowercase=True, stop_words="english")

X_train_vect = vectorizer.fit_transform(X_train).toarray()
X_test_vect = vectorizer.transform(X_test).toarray()

# # Build the Sequential model                                                                                  # uncomment it if using 1st time
# model = Sequential([
#     Dense(128, input_dim=X_train_vect.shape[1], activation="relu"),  # Input layer
#     Dropout(0.5),  # Dropout for regularization
#     Dense(64, activation="relu"),  # Hidden layer
#     Dropout(0.3),
#     Dense(1, activation="sigmoid")  # Output layer (binary classification)
# ])

# # Compile the model
# model.compile(optimizer=Adam(learning_rate=0.001), loss="binary_crossentropy", metrics=["accuracy"])

# # Train the model
# history = model.fit(X_train_vect, y_train, epochs=10, batch_size=32, validation_data=(X_test_vect, y_test))

#Load Model
# model=load_model("/content/drive/MyDrive/spam_mail_project/spam_model_efficient.h5")                            # uncomment it while using saved model



# Evaluate the model
y_pred = model.predict(X_test_vect)
y_pred = (y_pred > 0.5).astype(int)

# Calculate metrics
test_accuracy = accuracy_score(y_test, y_pred)
test_precision = precision_score(y_test, y_pred)
test_recall = recall_score(y_test, y_pred)
test_f1_score = f1_score(y_test, y_pred)

# Print metrics
print(f"Accuracy: {test_accuracy * 100:.2f}%")
print(f"Precision: {test_precision * 100:.2f}%")
print(f"Recall: {test_recall * 100:.2f}%")
print(f"F1 Score: {test_f1_score * 100:.2f}%")

# Save the model for reuse
# model.save("spam_model_efficient.h5")


# Make predictions on the test data
y_pred = model.predict(X_test_vect)

# Convert the probabilities to binary values (0 or 1)
y_pred = (y_pred > 0.5).astype(int)

# Compare predictions with actual labels
from sklearn.metrics import accuracy_score

test_accuracy = accuracy_score(y_test, y_pred)
test_precision = precision_score(y_test, y_pred)
test_recall = recall_score(y_test, y_pred)
test_f1_score = f1_score(y_test, y_pred)

# Print the evaluation metrics
print(f"Test Accuracy: {test_accuracy * 100:.2f}%")
print(f"Precision: {test_precision * 100:.2f}%")
print(f"Recall: {test_recall * 100:.2f}%")
print(f"F1 Score: {test_f1_score * 100:.2f}%")


# Get input from the user
# inx = input("Enter the message: ")

# Evaluate the model
y_pred = model.predict(X_test_vect)
y_pred_binary = (y_pred > 0.5).astype(int)  # Convert probabilities to binary values

# Calculate metrics
test_accuracy = accuracy_score(y_test, y_pred_binary)
test_precision = precision_score(y_test, y_pred_binary)
test_recall = recall_score(y_test, y_pred_binary)
test_f1_score = f1_score(y_test, y_pred_binary)

# Print evaluation results
print(f"Test Accuracy: {test_accuracy * 100:.2f}%")
print(f"Precision: {test_precision * 100:.2f}%")
print(f"Recall: {test_recall * 100:.2f}%")
print(f"F1 Score: {test_f1_score * 100:.2f}%")

# Make a prediction for user input
# input_message = input("Enter a message to classify: ")
user_input = "Dear Coder,Codecademy on Infosys Springboard empowers millions by equipping them with essential tech skills through engaging lessons and practical projects. Today thrilled to introduce an invaluable  resource for your learning journey - Interactive Skill Benchmarks"


user_input_vect = vectorizer.transform([user_input]).toarray()

# Make the prediction
y_pred = model.predict(user_input_vect)

print("SPAM" if y_pred > 0.5 else "NOT SPAM")
# Out:
# <ipython-input-11-78ba6e812c55>:17: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   labels = half_data["Category"].replace({"spam": 1, "ham": 0})  # Replace labels with 1 (spam) and 0 (ham)
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Accuracy: 98.92%
# Precision: 97.18%
# Recall: 94.52%
# F1 Score: 95.83%
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Test Accuracy: 98.92%
# Precision: 97.18%
# Recall: 94.52%
# F1 Score: 95.83%
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Test Accuracy: 98.92%
# Precision: 97.18%
# Recall: 94.52%
# F1 Score: 95.83%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# NOT SPAM
